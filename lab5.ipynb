# %% [markdown]
# # Лабораторная работа №5. Сверточные нейронные сети
# ## ПМ-21М
# ### Егор Решетников
#
# В данной лабораторной работе рассматривается решение задачи классификации посредством свёрточных нейронных сетей.
# Для построения сетей предлагается использовать [Keras](https://keras.io) на базе [TensorFlow](https://www.tensorflow.org).

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
import sklearn as sk
import sklearn.datasets
import sklearn.model_selection

mpl.rcParams['axes.grid'] = True

if tuple(map(int, tf.__version__.split('.'))) < (2, 5, 0):
    tf.autograph.set_verbosity(0)
    import logging
    logging.getLogger("tensorflow").setLevel(logging.ERROR)

# %% [markdown]
# ## Задание №1
#
# Загрузите датасет MNIST с помощью вызова `tf.keras.datasets.mnist.load_data()`.
# Промасштабируйте обучающую и тестовую выборки, чтобы входные значения лежали в отрезке $[0; 1]$.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = np.float32(x_train / x_train.max()).reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
y_train = y_train.reshape(y_train.shape[0], 1)
x_test = np.float32(x_test / x_test.max()).reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
y_test = y_test.reshape(y_test.shape[0], 1)

print(x_train.dtype, x_train.shape, y_train.shape)
assert x_train.dtype == np.float32 and x_test.dtype == np.float32, 'Неправильный тип входных данных'
assert x_train.shape[1:] == (28, 28, 1) and x_test.shape[1:] == (28, 28, 1), 'Неправильная размерность входных данных'
assert (x_train <= 1).all() and (x_test <= 1).all(), 'Неправильный диапазон входных данных'
# Out:
# float32 (60000, 28, 28, 1) (60000, 1)

# %% [markdown]
# Изучите приведённую ниже сеть с архитектурой:
#
# 1. Свёточный слой с 16 фильтрами размера $3\times3$ и функцией активации relu
# 1. Слой MaxPooling с размером шага 2
# 1. Свёточный слой с 32 фильтрами размера $3\times3$ и функцией активации relu
# 1. Слой MaxPooling с размером шага 2
# 1. Свёточный слой с 64 фильтрами размера $3\times3$ и функцией активации relu
# 1. Слой линеаризации
# 1. Полносвязный слой с количеством нейронов равным количеству выходных классов с функцией активации softmax
#
# В качестве градиетного спуска выступает SGD, размер батча определяется при обучении модели.
# Для вычисления функции потерь используется кросс-энтропия по категориям с автоматическим OneHot кодированием.
# Метрика точности соответствует $accuracy(\tilde{y}, y) = \frac{1}{N} \sum_{n=0}^{N-1} 1(\tilde{y}_n = y_n)$.
# При этом точное название метрики `sparse_categorical_accuracy`, которое можно сократить до `accuracy`, так как метрика выбирается согласно функции потерь.
#
# Запустите нейросеть.
# Итоговая точность должна получится около 92% или больше.

# %%
# %%time

def create_model1(input_x, input_y):
    inputs = tf.keras.layers.Input(shape=input_x.shape[1:])
    x = tf.keras.layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(inputs)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(len(np.unique(input_y)), activation='softmax')(x)
    
    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

model = create_model1(x_train, y_train)
model.fit(x_train, y_train, batch_size=128, epochs=3, validation_data=(x_test, y_test), verbose=True)
score = model.evaluate(x_test, y_test, verbose=0)
print(dict(zip(model.metrics_names, score)))

y_pred = model(x_test)
print('y_test', y_test[:2], 'y_pred', y_pred[:2])
# Out:
# WARNING:tensorflow:From C:\Users\EReshetnikov\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\EReshetnikov\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\EReshetnikov\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          18496
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
# =================================================================
# Total params: 54666 (213.54 KB)
# Trainable params: 54666 (213.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/3
# WARNING:tensorflow:From C:\Users\EReshetnikov\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\EReshetnikov\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 469/469 [==============================] - 14s 28ms/step - loss: 1.2223 - accuracy: 0.6454 - val_loss: 0.3586 - val_accuracy: 0.8986
# Epoch 2/3
# 469/469 [==============================] - 13s 28ms/step - loss: 0.2994 - accuracy: 0.9111 - val_loss: 0.2419 - val_accuracy: 0.9293
# Epoch 3/3
# 469/469 [==============================] - 12s 27ms/step - loss: 0.2121 - accuracy: 0.9372 - val_loss: 0.1707 - val_accuracy: 0.9494
# {'loss': 0.17074885964393616, 'accuracy': 0.949400007724762}
# y_test [[7]
#  [2]] y_pred tf.Tensor(
# [[9.0508240e-07 6.6425896e-09 3.0072638e-06 7.0021233e-05 9.0794652e-09
#   1.5849538e-06 2.0803743e-10 9.9940264e-01 6.5965821e-07 5.2117609e-04]
#  [1.2485663e-04 1.3695839e-04 9.9812645e-01 9.2691148e-04 9.8301489e-10
#   4.6408557e-05 5.5129785e-04 2.9929070e-10 8.7227418e-05 7.4193894e-11]], shape=(2, 10), dtype=float32)
# CPU times: total: 3min 21s
# Wall time: 43.6 s

# %% [markdown]
# **Вопросы**:
#
# 1. Сколько всего параметров у нейронной сети?
# 1. Сколько всего участвует в обучении векторов из обучающей выборки?
# 1. Какая точность достигнута?
# 1. В обучающей выборке в качестве классов используются числа от 0 до 9.
# Что получается на выходе у нейронной сети?
# Как выходные значения нейронной сети преобразовать в номер класса?
#
# **Ответы**:
#
# 1. 5466
# 2. 60 000
# 3. 0.94
# 4. На выходе вектор из вероятностей. Берется тот класс, номер которого соответствует максимальной вероятности

# %% [markdown]
# ## Задание №2
#
# Попробуйте увеличить точность классификации, например, добавив после каждого свёрточного слоя нормализацию (BatchNormalization) или изменив архитектуру сети.
# Объясните целесообразность произведенных изменений.

# %%
# %%time

def create_model2(input_x, input_y):
    inputs = tf.keras.layers.Input(shape=input_x.shape[1:])
    x = tf.keras.layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)

    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)

    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Flatten()(x)

    outputs = tf.keras.layers.Dense(len(np.unique(input_y)), activation='softmax')(x)
    
    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

model = create_model2(x_train, y_train)
model.fit(x_train, y_train, batch_size=128, epochs=3, validation_data=(x_test, y_test), verbose=True)
score = model.evaluate(x_test, y_test, verbose=0)
print(dict(zip(model.metrics_names, score)))
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 16)        160
#
#  batch_normalization_8 (Bat  (None, 28, 28, 16)        64
#  chNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 32)        4640
#
#  batch_normalization_9 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 64)          18496
#
#  batch_normalization_10 (Ba  (None, 7, 7, 64)          256
#  tchNormalization)
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 10)                31370
#
# =================================================================
# Total params: 55114 (215.29 KB)
# Trainable params: 54890 (214.41 KB)
# Non-trainable params: 224 (896.00 Byte)
# _________________________________________________________________
# Epoch 1/3
# 469/469 [==============================] - 15s 30ms/step - loss: 0.1994 - accuracy: 0.9415 - val_loss: 0.3903 - val_accuracy: 0.8905
# Epoch 2/3
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0772 - accuracy: 0.9781 - val_loss: 0.0639 - val_accuracy: 0.9811
# Epoch 3/3
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0579 - accuracy: 0.9839 - val_loss: 0.0530 - val_accuracy: 0.9852
# {'loss': 0.052976079285144806, 'accuracy': 0.9851999878883362}
# CPU times: total: 3min 43s
# Wall time: 44.2 s

# %% [markdown]
# **Вопросы:**
#
# 1. Почему появились необучаемые параметры (non-trainable)?
# 1. Распишите, какие и сколько параметров входят в BatchNormalization. Для этого воспользуйтесь переменной `layers` и методом `get_weights`.
# 1. Сколько параметров используется на каждом batch normalization слое?
# 1. Какая итоговая точность получилась? Стала ли она больше?
# 1. Как введение новых слоёв повлияло на вермя обучения сети?
# 1. Попробуйте поставить BatchNormalization слои перед/после MaxPooling. Как меняются характеристики и время обучения?
#
# **Ответы:**
#
# 1. Слой нормализации не изменяется
# 2. gamma weights (веса масштабирования, отвечающие за изменение масштаба (умножение) активаций), beta weights (Веса сдвига, отвечающие за изменение среднего (смещение) активаций), moving_mean(скользящее среднее, используемое в инференсе для нормализации данных), moving_variance(скользящая дисперсия, используемая в инференсе для нормализации данных)
# 3. Число параметров в четыре раза превышает последнюю размерность входного вектора, которая в свою очередь равна размерности предыдущего вектора
# 4. Количество параметров, используемых на каждом слое BatchNormalization, зависит от размера фильтров в предыдущем сверточном слое. Слой BatchNormalization содержит четыре типа параметров для каждого фильтра.
# 5. Итоговая точность увеличилась на 0.04 и стала равна 0.98
# 6. Время обучение выросло примерно в 30%
# 7. Результаты не очень изменились

# %% [markdown]
# ## Задание №3
#
# Визуализируйте результат воздействия весов последней сети с первого свёрточного слоя на одно из тестовых изображений.

# %%
import matplotlib.pyplot as plt

model = create_model5(x_train, y_train)
conv_layer = model.get_layer(index=1)
activation_model = tf.keras.models.Model(inputs=model.input, outputs=conv_layer.output)
activation = activation_model.predict(x_test[10:11])
plt.grid(False)
plt.imshow(x_test[10, :, :, 0], cmap='gray')
plt.title('Original Image')
plt.show()
fig, axes = plt.subplots(4, 4, figsize=(4*4, 4*4))
for row, ax_rows in enumerate(axes):
    for col, ax in enumerate(ax_rows):
        ax.imshow(activation[0, :, :, col], cmap='viridis')  # Visualize the activation of each filter
        ax.grid(False)
        ax.set_title(f'Filter {col+1}')
plt.show()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 16)        160
#
#  max_pooling2d_10 (MaxPooli  (None, 14, 14, 16)        0
#  ng2D)
#
#  batch_normalization_11 (Ba  (None, 14, 14, 16)        64
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 32)        4640
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  batch_normalization_12 (Ba  (None, 7, 7, 32)          128
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 7, 7, 64)          18496
#
#  flatten_5 (Flatten)         (None, 3136)              0
#
#  dense_5 (Dense)             (None, 10)                31370
#
# =================================================================
# Total params: 54858 (214.29 KB)
# Trainable params: 54762 (213.91 KB)
# Non-trainable params: 96 (384.00 Byte)
# _________________________________________________________________
# 1/1 [==============================] - 0s 70ms/step

# %% [markdown]
# **Вопросы:**
#
# 1. На что похожи отклики с первого слоя?

# %% [markdown]
# **Ответы:**
#
# 1. Визуально, отклики могут выглядеть как сглаженные версии изображения, где различные фильтры выделяют разные аспекты текстуры или структуры.

# %% [markdown]
# ## Задание №4
#
# Подготовьте датасет [cifar10](https://keras.io/api/datasets/) аналогично предыдущему датасету.
# Во время первого запуска будет скачиваться архив (около 170 МБ).
# Он будет закеширован локально, поэтому последующие загрузки этого датасета будут занимать меньше времени.
#
# Покажите 4 произвольных изображения из обучающей выборки.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train = np.float32(x_train / x_train.max())
y_train = y_train.reshape(y_train.shape[0], 1)

x_test = np.float32(x_test / x_test.max())
y_test = y_test.reshape(y_test.shape[0], 1)

print(x_train.shape, x_train.dtype, y_train.shape, y_train.dtype, y_test.shape)

assert x_train.dtype == np.float32 and x_test.dtype == np.float32, 'Неправильный тип входных данных'
assert (x_train <= 1).all() and (x_test <= 1).all(), 'Данные не отмасштабированы'

fig, axes = plt.subplots(1, 4, figsize=(4 * 4, 4 * 4))
for k, ax in enumerate(axes):
    ax.imshow(x_train[k])
    ax.grid(False)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 332s 2us/step
# (50000, 32, 32, 3) float32 (50000, 1) uint8 (10000, 1)

# %% [markdown]
# Постройте сеть с такой архитектурой:
# ```
# convolution2dLayer: 32, 3x3, 'Padding'=1
# reluLayer
# maxPooling2dLayer: 2, 'Padding'=0
#
# convolution2dLayer: 32, 3x3, 'Padding'=1
# reluLayer
# maxPooling2dLayer: 2, 'Padding'=0
#
# convolution2dLayer: 64, 3, 'Padding'=1
# reluLayer
# maxPooling2dLayer: 2, 'Padding'=0
#
# fullyConnectedLayer: 128
# reluLayer
# fullyConnectedLayer: num_classes
# softmaxLayer
# ```
#
# Изображения цветные, поэтому для первого слоя с конволюцией укажите параметр `data_format='channels_last'`.
# При обучении используйте 15 эпох, размер батча 128, оптимизатор градиентного спуска - SGD.
# Также можно использовать любую другую архитектуру, объяснив целесообразность её применения.
# Протестируйте работу данной сети.
# Время обучения сети 5-10 минут.

# %%
# %%time

def create_model4(input_x, input_y):
    inputs = tf.keras.layers.Input(shape=input_x.shape[1:])
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', data_format='channels_last')(inputs)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(units = 128, activation='relu')(x)
    outputs = tf.keras.layers.Dense(len(np.unique(input_y)), activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

model = create_model4(x_train, y_train)
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test), verbose=True)
score = model.evaluate(x_test, y_test, verbose=0)
print(dict(zip(model.metrics_names, score)))
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_12 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_13 (MaxPooli  (None, 8, 8, 32)          0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 64)          18496
#
#  max_pooling2d_14 (MaxPooli  (None, 4, 4, 64)          0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 128)               131200
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 161130 (629.41 KB)
# Trainable params: 161130 (629.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 391/391 [==============================] - 18s 44ms/step - loss: 2.2161 - accuracy: 0.2058 - val_loss: 2.0524 - val_accuracy: 0.2610
# Epoch 2/15
# 391/391 [==============================] - 16s 41ms/step - loss: 1.9823 - accuracy: 0.2894 - val_loss: 1.9093 - val_accuracy: 0.3026
# Epoch 3/15
# 391/391 [==============================] - 17s 45ms/step - loss: 1.8655 - accuracy: 0.3331 - val_loss: 1.7992 - val_accuracy: 0.3563
# Epoch 4/15
# 391/391 [==============================] - 17s 44ms/step - loss: 1.7640 - accuracy: 0.3702 - val_loss: 1.7797 - val_accuracy: 0.3606
# Epoch 5/15
# 391/391 [==============================] - 16s 41ms/step - loss: 1.6699 - accuracy: 0.4040 - val_loss: 1.6152 - val_accuracy: 0.4171
# Epoch 6/15
# 391/391 [==============================] - 16s 40ms/step - loss: 1.5912 - accuracy: 0.4329 - val_loss: 1.5254 - val_accuracy: 0.4488
# Epoch 7/15
# 391/391 [==============================] - 16s 42ms/step - loss: 1.5250 - accuracy: 0.4546 - val_loss: 1.4677 - val_accuracy: 0.4672
# Epoch 8/15
# 391/391 [==============================] - 17s 43ms/step - loss: 1.4760 - accuracy: 0.4747 - val_loss: 1.5156 - val_accuracy: 0.4528
# Epoch 9/15
# 391/391 [==============================] - 18s 46ms/step - loss: 1.4336 - accuracy: 0.4903 - val_loss: 1.4097 - val_accuracy: 0.4970
# Epoch 10/15
# 391/391 [==============================] - 18s 47ms/step - loss: 1.3960 - accuracy: 0.5028 - val_loss: 1.4374 - val_accuracy: 0.4852
# Epoch 11/15
# 391/391 [==============================] - 16s 42ms/step - loss: 1.3653 - accuracy: 0.5181 - val_loss: 1.3940 - val_accuracy: 0.5021
# Epoch 12/15
# 391/391 [==============================] - 15s 39ms/step - loss: 1.3316 - accuracy: 0.5274 - val_loss: 1.4067 - val_accuracy: 0.4979
# Epoch 13/15
# 391/391 [==============================] - 16s 41ms/step - loss: 1.3037 - accuracy: 0.5409 - val_loss: 1.3258 - val_accuracy: 0.5296
# Epoch 14/15
# 391/391 [==============================] - 17s 42ms/step - loss: 1.2769 - accuracy: 0.5511 - val_loss: 1.3018 - val_accuracy: 0.5338
# Epoch 15/15
# 391/391 [==============================] - 17s 43ms/step - loss: 1.2475 - accuracy: 0.5616 - val_loss: 1.3260 - val_accuracy: 0.5212
# {'loss': 1.3259717226028442, 'accuracy': 0.5212000012397766}
# CPU times: total: 22min 58s
# Wall time: 4min 12s

# %% [markdown]
# **Вопросы:**
#
# 1. Какую точность классификации удалось получить?
# 1. Какие слои не имеют параметров обучения? Почему?
# 1. Какую размерность имеют входные изображения?
#
# **Ответы:**
#
# 1. 0.51
# 2. У входного слоя, так как определение максимума не требует параметров, то и у слоёв пулинга нет параметров, и выравнивания
# 3. 32x32

# %% [markdown]
# ## Задание №5
#
# Попробуйте улучшить точность классификации, добавив нормализацию после свёрточных и полносвязных слоёв.

# %%
# %%time

def create_model5(input_x, input_y):
    inputs = tf.keras.layers.Input(shape=input_x.shape[1:])
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', data_format='channels_last')(inputs)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(units = 128, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    outputs = tf.keras.layers.Dense(len(np.unique(input_y)), activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

model = create_model5(x_train, y_train)
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test), verbose=True)
score = model.evaluate(x_test, y_test, verbose=0)
print(dict(zip(model.metrics_names, score)))
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_15 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  batch_normalization_13 (Ba  (None, 16, 16, 32)        128
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_16 (MaxPooli  (None, 8, 8, 32)          0
#  ng2D)
#
#  batch_normalization_14 (Ba  (None, 8, 8, 32)          128
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 64)          18496
#
#  max_pooling2d_17 (MaxPooli  (None, 4, 4, 64)          0
#  ng2D)
#
#  batch_normalization_15 (Ba  (None, 4, 4, 64)          256
#  tchNormalization)
#
#  flatten_7 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 128)               131200
#
#  batch_normalization_16 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 162154 (633.41 KB)
# Trainable params: 161642 (631.41 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/15
# 391/391 [==============================] - 16s 40ms/step - loss: 1.6155 - accuracy: 0.4346 - val_loss: 1.7042 - val_accuracy: 0.3825
# Epoch 2/15
# 391/391 [==============================] - 18s 47ms/step - loss: 1.2556 - accuracy: 0.5568 - val_loss: 1.4885 - val_accuracy: 0.4927
# Epoch 3/15
# 391/391 [==============================] - 19s 49ms/step - loss: 1.1123 - accuracy: 0.6110 - val_loss: 1.1871 - val_accuracy: 0.5821
# Epoch 4/15
# 391/391 [==============================] - 19s 49ms/step - loss: 1.0117 - accuracy: 0.6465 - val_loss: 1.2318 - val_accuracy: 0.5714
# Epoch 5/15
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9419 - accuracy: 0.6715 - val_loss: 1.0985 - val_accuracy: 0.6134
# Epoch 6/15
# 391/391 [==============================] - 20s 50ms/step - loss: 0.8837 - accuracy: 0.6950 - val_loss: 1.3239 - val_accuracy: 0.5527
# Epoch 7/15
# 391/391 [==============================] - 19s 48ms/step - loss: 0.8341 - accuracy: 0.7095 - val_loss: 1.0027 - val_accuracy: 0.6551
# Epoch 8/15
# 391/391 [==============================] - 19s 50ms/step - loss: 0.7929 - accuracy: 0.7262 - val_loss: 1.1129 - val_accuracy: 0.6174
# Epoch 9/15
# 391/391 [==============================] - 19s 49ms/step - loss: 0.7575 - accuracy: 0.7392 - val_loss: 1.0207 - val_accuracy: 0.6412
# Epoch 10/15
# 391/391 [==============================] - 20s 50ms/step - loss: 0.7253 - accuracy: 0.7489 - val_loss: 1.0175 - val_accuracy: 0.6451
# Epoch 11/15
# 391/391 [==============================] - 20s 50ms/step - loss: 0.6954 - accuracy: 0.7623 - val_loss: 1.4537 - val_accuracy: 0.5424
# Epoch 12/15
# 391/391 [==============================] - 19s 49ms/step - loss: 0.6671 - accuracy: 0.7691 - val_loss: 1.1990 - val_accuracy: 0.5987
# Epoch 13/15
# 391/391 [==============================] - 20s 50ms/step - loss: 0.6422 - accuracy: 0.7794 - val_loss: 1.0386 - val_accuracy: 0.6435
# Epoch 14/15
# 391/391 [==============================] - 20s 51ms/step - loss: 0.6189 - accuracy: 0.7871 - val_loss: 1.0667 - val_accuracy: 0.6444
# Epoch 15/15
# 391/391 [==============================] - 21s 54ms/step - loss: 0.5913 - accuracy: 0.7981 - val_loss: 1.0339 - val_accuracy: 0.6547
# {'loss': 1.0338537693023682, 'accuracy': 0.654699981212616}
# CPU times: total: 25min 1s
# Wall time: 4min 51s

# %% [markdown]
# **Вопросы:**
#
# 1. Удалось ли увеличить точность классификации введением новых слоёв?
# 1. Как изменилось время обучения сети? (Обратите внимание на `Wall time`, `total`, а также на время обучения каждой эпохи)

# %% [markdown]
# **Ответы:**
#
# 1. Да
# 1. CPU time немного выросло, Wall time почти не изменилось

# %% [markdown]
# ## Задание №6
#
# Попробуйте добавить слой dropout `tf.keras.layers.Dropout(<probability>)` после полносвязного слоя, подобрав оптимальную на Ваш взгляд вероятность удаления нейронов.
# Поэкспериментируйте с добавлением слоёв BatchNormalization и без них.

# %%
# %%time

def create_model6(input_x, input_y):
    inputs = tf.keras.layers.Input(shape=input_x.shape[1:])
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', data_format='channels_last')(inputs)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding='valid')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(units = 128, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(rate = 0.1)(x)
    outputs = tf.keras.layers.Dense(len(np.unique(input_y)), activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

model = create_model6(x_train, y_train)
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test), verbose=True)
score = model.evaluate(x_test, y_test, verbose=0)
print(dict(zip(model.metrics_names, score)))
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_18 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  batch_normalization_17 (Ba  (None, 16, 16, 32)        128
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_19 (MaxPooli  (None, 8, 8, 32)          0
#  ng2D)
#
#  batch_normalization_18 (Ba  (None, 8, 8, 32)          128
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 64)          18496
#
#  max_pooling2d_20 (MaxPooli  (None, 4, 4, 64)          0
#  ng2D)
#
#  batch_normalization_19 (Ba  (None, 4, 4, 64)          256
#  tchNormalization)
#
#  flatten_8 (Flatten)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 128)               131200
#
#  batch_normalization_20 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 162154 (633.41 KB)
# Trainable params: 161642 (631.41 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/15
# 391/391 [==============================] - 17s 41ms/step - loss: 1.6707 - accuracy: 0.4172 - val_loss: 1.9620 - val_accuracy: 0.3169
# Epoch 2/15
# 391/391 [==============================] - 19s 48ms/step - loss: 1.3177 - accuracy: 0.5338 - val_loss: 1.3203 - val_accuracy: 0.5270
# Epoch 3/15
# 391/391 [==============================] - 19s 48ms/step - loss: 1.1736 - accuracy: 0.5855 - val_loss: 1.4290 - val_accuracy: 0.5118
# Epoch 4/15
# 391/391 [==============================] - 20s 50ms/step - loss: 1.0835 - accuracy: 0.6205 - val_loss: 1.1678 - val_accuracy: 0.5926
# Epoch 5/15
# 391/391 [==============================] - 19s 48ms/step - loss: 1.0101 - accuracy: 0.6465 - val_loss: 1.0746 - val_accuracy: 0.6274
# Epoch 6/15
# 391/391 [==============================] - 20s 50ms/step - loss: 0.9565 - accuracy: 0.6665 - val_loss: 1.3518 - val_accuracy: 0.5272
# Epoch 7/15
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9041 - accuracy: 0.6849 - val_loss: 1.0123 - val_accuracy: 0.6471
# Epoch 8/15
# 391/391 [==============================] - 19s 50ms/step - loss: 0.8680 - accuracy: 0.6965 - val_loss: 1.7527 - val_accuracy: 0.4525
# Epoch 9/15
# 391/391 [==============================] - 20s 50ms/step - loss: 0.8310 - accuracy: 0.7098 - val_loss: 1.1743 - val_accuracy: 0.6040
# Epoch 10/15
# 391/391 [==============================] - 19s 50ms/step - loss: 0.8061 - accuracy: 0.7166 - val_loss: 0.9969 - val_accuracy: 0.6585
# Epoch 11/15
# 391/391 [==============================] - 19s 48ms/step - loss: 0.7714 - accuracy: 0.7308 - val_loss: 1.0135 - val_accuracy: 0.6515
# Epoch 12/15
# 391/391 [==============================] - 19s 49ms/step - loss: 0.7460 - accuracy: 0.7405 - val_loss: 1.1366 - val_accuracy: 0.6092
# Epoch 13/15
# 391/391 [==============================] - 19s 48ms/step - loss: 0.7178 - accuracy: 0.7498 - val_loss: 1.3756 - val_accuracy: 0.5569
# Epoch 14/15
# 391/391 [==============================] - 19s 48ms/step - loss: 0.6989 - accuracy: 0.7588 - val_loss: 0.8905 - val_accuracy: 0.6934
# Epoch 15/15
# 391/391 [==============================] - 20s 50ms/step - loss: 0.6774 - accuracy: 0.7658 - val_loss: 1.1245 - val_accuracy: 0.6222
# {'loss': 1.1245269775390625, 'accuracy': 0.6222000122070312}
# CPU times: total: 25min 15s
# Wall time: 4min 47s

# %% [markdown]
# **Вопросы:**
#
# 1. Удалось ли увеличить точность классификации?
# 1. Что влияет больше на увеличение точности: слой Dropout или BatchNormalization?
# 1. Как изменилось время обучения?

# %% [markdown]
# **Ответы:**
#
# 1. Нет
# 2. BatchNormalization
# 3. Время обучения не изменилось
